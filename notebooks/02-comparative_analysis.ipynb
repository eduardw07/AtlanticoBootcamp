# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/edu/Downloads/drinks.csv")

# %%
valores_faltantes = df.isnull().sum()
print(valores_faltantes)
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# dtype: int64

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
df2 = df.drop("country", axis =1)

# %%
df2.dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
plt.boxplot([df2["beer_servings"], df2["spirit_servings"], df2["wine_servings"], df2["total_litres_of_pure_alcohol"]], labels = ["Cerveja", "Destilados", "Vinhos", "Total de litros"])
plt.title("Boxplot para analisar as outliers")
plt.show()
